-- %% [markdown]
-- # [ServicioTransferencias]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ServicioTransferencias]    Script Date: 9/5/2023 20:25:28 ******/
CREATE DATABASE [ServicioTransferencias]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ServicioTransferencias', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\ServicioTransferencias.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ServicioTransferencias_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\ServicioTransferencias_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [ServicioTransferencias] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ServicioTransferencias].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ServicioTransferencias] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET ARITHABORT OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ServicioTransferencias] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ServicioTransferencias] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ServicioTransferencias] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ServicioTransferencias] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [ServicioTransferencias] SET  MULTI_USER 
GO
ALTER DATABASE [ServicioTransferencias] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ServicioTransferencias] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ServicioTransferencias] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ServicioTransferencias] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ServicioTransferencias] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ServicioTransferencias] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [ServicioTransferencias] SET QUERY_STORE = ON
GO
ALTER DATABASE [ServicioTransferencias] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Respuestas]

-- %%
USE [ServicioTransferencias]
GO

-- %%
/****** Object:  Table [dbo].[Respuestas]    Script Date: 9/5/2023 20:25:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Respuestas](
	[id] [int] NOT NULL,
	[idTransferencia] [int] NULL,
	[resultado] [varchar](50) NULL,
	[importe] [decimal](18, 2) NULL,
	[cuentaOrigen] [varchar](50) NULL,
	[cuentaDestino] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Transferencias]

-- %%
/****** Object:  Table [dbo].[Transferencias]    Script Date: 9/5/2023 20:25:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Transferencias](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[cuilOriginante] [varchar](50) NULL,
	[cuilDestinatario] [varchar](50) NULL,
	[cbuOrigen] [varchar](50) NULL,
	[cbuDestino] [varchar](50) NULL,
	[importe] [decimal](18, 2) NULL,
	[concepto] [varchar](50) NULL,
	[descripcion] [varchar](50) NULL,
 CONSTRAINT [PK_Transferencias] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [ServicioTransferencias]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ServicioTransferencias] SET  READ_WRITE 
GO
