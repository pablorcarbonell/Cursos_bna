-- %% [markdown]
-- # [microservicio]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [microservicio]    Script Date: 9/5/2023 20:24:38 ******/
CREATE DATABASE [microservicio]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'microservicio', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\microservicio.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'microservicio_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\microservicio_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [microservicio] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [microservicio].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [microservicio] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [microservicio] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [microservicio] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [microservicio] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [microservicio] SET ARITHABORT OFF 
GO
ALTER DATABASE [microservicio] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [microservicio] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [microservicio] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [microservicio] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [microservicio] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [microservicio] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [microservicio] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [microservicio] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [microservicio] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [microservicio] SET  DISABLE_BROKER 
GO
ALTER DATABASE [microservicio] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [microservicio] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [microservicio] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [microservicio] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [microservicio] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [microservicio] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [microservicio] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [microservicio] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [microservicio] SET  MULTI_USER 
GO
ALTER DATABASE [microservicio] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [microservicio] SET DB_CHAINING OFF 
GO
ALTER DATABASE [microservicio] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [microservicio] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [microservicio] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [microservicio] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [microservicio] SET QUERY_STORE = ON
GO
ALTER DATABASE [microservicio] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
USE [microservicio]
GO

-- %%
/****** Object:  Table [dbo].[Clientes]    Script Date: 9/5/2023 20:24:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](50) NULL,
	[apellido] [varchar](50) NULL,
	[cuil] [varchar](50) NULL,
	[tipoDocumento] [varchar](10) NULL,
	[nroDocumento] [int] NULL,
	[esEmpleadoBNA] [bit] NULL,
	[paisOrigen] [varchar](50) NULL,
 CONSTRAINT [PK_Clientes] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %%
SET IDENTITY_INSERT [dbo].[Clientes] ON 
INSERT [dbo].[Clientes] ([id], [nombre], [apellido], [cuil], [tipoDocumento], [nroDocumento], [esEmpleadoBNA], [paisOrigen]) VALUES (1, N'Juan', N'Perez', N'20123456789', N'DNI', 12345678, 1, N'Argentina')
INSERT [dbo].[Clientes] ([id], [nombre], [apellido], [cuil], [tipoDocumento], [nroDocumento], [esEmpleadoBNA], [paisOrigen]) VALUES (2, N'Roberto', N'Gomez', N'24202020857', N'DNI', 20202085, 0, N'Argentina')
INSERT [dbo].[Clientes] ([id], [nombre], [apellido], [cuil], [tipoDocumento], [nroDocumento], [esEmpleadoBNA], [paisOrigen]) VALUES (3, N'Alfredo', N'Mercurio', N'20901234564', N'DNI', 90123456, 0, N'Inglaterra')
INSERT [dbo].[Clientes] ([id], [nombre], [apellido], [cuil], [tipoDocumento], [nroDocumento], [esEmpleadoBNA], [paisOrigen]) VALUES (5, N'Victor', N'Mendieta', N'20551234564', N'DNI', 55123456, 1, N'Argentina')
SET IDENTITY_INSERT [dbo].[Clientes] OFF
GO

-- %% [markdown]
-- # [microservicio]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [microservicio] SET  READ_WRITE 
GO
